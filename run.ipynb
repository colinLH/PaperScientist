# %%
from collector import create_search_agent

create_search_agent()
# Out:
# 🧭 [classify intent] Classifying intent...
# ================================== Ai Message ==================================
#
# literature_collection
#
# 📚 [collect paper] Paper collecting...
# ================================== Ai Message ==================================
#
# I'll start by searching for the latest papers on LLM agents for fuzzing from 2025-2026.
# Tool Calls:
#   serp_google_scholar_search (call_00_5orsvitPYiGHp7tCgcFa7484)
#  Call ID: call_00_5orsvitPYiGHp7tCgcFa7484
#   Args:
#     query: LLM agent fuzzing 2025
#     as_ylo: 2025
#     as_yhi: 2026
#     max_results: 10
#   tavily_web_search (call_01_VBvycSMJxcMYb0ORMlEq9443)
#  Call ID: call_01_VBvycSMJxcMYb0ORMlEq9443
#   Args:
#     query: LLM agent for fuzzing 2025 2026 paper
# 🔍 [collect_paper] Tool: serp_google_scholar_search
# 🔍 [collect_paper] Tool: tavily_web_search
#
# 📚 [collect paper] Paper collecting...
# ================================== Ai Message ==================================
#
# ...
